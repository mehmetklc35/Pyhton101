# %% [markdown]
# # Django
#
# pycharm'ı kur
# datagrip'i kur
#
# Django tıpkı Flask gibi hızlı bir şekilde proje geliştirmemizi sağlayan ve bizim direkt son ürünümüze odaklamamızı sağlayan %100 python ile yazılmış bir web framework'üdür. İçerisinde çok fazla hazır modül bulunmaktadır ve biz bu modüller sayesinde çok hızlı geliştirme yapabilmekteyiz.

# %%
from IPython.display import Image
Image(filename='images/django_ozellikleri.png')

# %% [markdown]
# Django hızlıca ürün çıkarılabileceği ve çok güçlü bir web frameworkü olması sebebiyle hem türkiyedeki hem de dünyadaki start up'ların gözdesi konumundadır.
